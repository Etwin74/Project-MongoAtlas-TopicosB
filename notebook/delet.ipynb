# %% [markdown]
# # Eliminar documentos

# %%
from connect import db
elimiar = db['libros']

# Delete One
res = elimiar.delete_one({'titulo': '1984'})
print('Documentos eliminados:', res.deleted_count)
# Out:
# Documentos eliminados: 1
